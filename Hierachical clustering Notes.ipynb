# %% [markdown]
#  In K-means clustering we to predetermine number of clusters

# %% [markdown]
# # Agglomerative Hierarchical clustering

# %% [markdown]
# The agglomerative hierarchical clustering algorithm groups datasets into clusters, it follows the bottom-up approach.

# %% [markdown]
# This algorithm considers each dataset(data point) as a single cluster at the beginning, and then start combining the closest pair of clusters together. It does this until all the clusters are merged into a single cluster that contains all the datasets.

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning.png](attachment:hierarchical-clustering-in-machine-learning.png)

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning2.png](attachment:hierarchical-clustering-in-machine-learning2.png)

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning3.png](attachment:hierarchical-clustering-in-machine-learning3.png)

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning4.png](attachment:hierarchical-clustering-in-machine-learning4.png)

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning5.png](attachment:hierarchical-clustering-in-machine-learning5.png)

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning6.png](attachment:hierarchical-clustering-in-machine-learning6.png)

# %% [markdown]
# # Dendrogram in Hierarchical clustering

# %% [markdown]
# The dendrogram is a tree-like structure that is mainly used to store each step as a memory that the HC algorithm performs. In the dendrogram plot, the Y-axis shows the Euclidean distances between the data points, and the x-axis shows all the data points of the given dataset.

# %% [markdown]
# ![hierarchical-clustering-in-machine-learning10.png](attachment:hierarchical-clustering-in-machine-learning10.png)
