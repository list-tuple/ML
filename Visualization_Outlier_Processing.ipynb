# %%
import pandas as pd

# %%
df= pd.read_excel("Global Superstore1.xls","Orders")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                 float64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline

# %%
sns.displot(df["Sales"])

# %%
sns.displot(df["Profit"])

# %%
sns.lmplot(x="Discount",y="Profit",data=df)

# %%
sns.lmplot(x="Quantity",y="Shipping Cost",data=df)

# %%
sns.lmplot(x="Shipping Cost",y="Profit",data=df)

# %%
sns.countplot(x='Quantity',data=df)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='count'>

# %%
sns.catplot(x='Sales',y='Discount',col='Category',data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 sns.catplot(x='Sales',y='Discount',col='Category',data=df)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.lineplot(x='Discount',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
sns.catplot(x='Category',y='Profit',kind="box",data=df)

# %%
sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df)

# %%
sns.catplot(x='Ship Mode',kind="count",data=df)

# %%
plt.figure(figsize=(25,20))
g=sns.barplot(x='Discount',y='Profit',hue='Category',data=df)

# %%
df2=df.drop(['Row ID','Order ID','Postal Code'],axis=1)

# %%
sns.pairplot(data=df2)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Sales", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Sales',y='Discount',s=df['Profit'].values,hue='Category',data=df)
# Out:
# C:\Users\Lalith Eswar\anaconda3\lib\site-packages\matplotlib\collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# C:\Users\Lalith Eswar\anaconda3\lib\site-packages\seaborn\relational.py:634: RuntimeWarning: invalid value encountered in sqrt
#   kws.setdefault("linewidth", .08 * np.sqrt(np.percentile(s, 10)))
# C:\Users\Lalith Eswar\anaconda3\lib\site-packages\matplotlib\collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='Sales', ylabel='Discount'>
# Error in callback <function flush_figures at 0x000001E4782AC5E0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:121, in flush_figures()
# ...

# %%
sns.barplot(x='Market',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Market', ylabel='Profit'>

# %%
sns.boxplot(x='Market',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Market', ylabel='Profit'>

# %%
df4=df[["Sales","Profit","Discount","Shipping Cost","Quantity"]]

# %%
df4_corr = df4.corr()

# %%
sns.heatmap(data=df4_corr,cmap="rainbow",annot=True)
# Out:
# <AxesSubplot:>

# %%
df4.describe()
# Out:
#               Sales        Profit      Discount  Shipping Cost      Quantity
# count  51290.000000  51290.000000  51290.000000   51284.000000  51285.000000
# mean     246.490581     28.610982      0.142908      26.303714      3.476260
# std      487.565361    174.340972      0.212280      56.898113      2.278424
# min        0.444000  -6599.978000      0.000000       0.002000      1.000000
# 25%       30.758625      0.000000      0.000000       2.610000      2.000000
# 50%       85.053000      9.240000      0.000000       7.790000      3.000000
# 75%      251.053200     36.810000      0.200000      24.440250      5.000000
# max    22638.480000   8399.976000      0.850000     933.570000     14.000000

# %%
plt.boxplot(df4["Profit"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e40e4977f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e40e4978b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e40e497460>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e40ea8d5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e40ea05a90>],
#  'means': []}

# %%
df4["Profit"].quantile([0.1,0.25,0.50,0.75,1.0])
# Out:
# 0.10     -30.5712
# 0.25       0.0000
# 0.50       9.2400
# 0.75      36.8100
# 1.00    8399.9760
# Name: Profit, dtype: float64

# %%
df4["Sales"].quantile([0.1,0.25,0.50,0.75,1.0])
# Out:
# 0.10       13.680000
# 0.25       30.758625
# 0.50       85.053000
# 0.75      251.053200
# 1.00    22638.480000
# Name: Sales, dtype: float64

# %%
df4["Discount"].quantile([0.1,0.25,0.50,0.75,1.0])
# Out:
# 0.10    0.00
# 0.25    0.00
# 0.50    0.00
# 0.75    0.20
# 1.00    0.85
# Name: Discount, dtype: float64

# %%
df4["Shipping Cost"].quantile([0.1,0.25,0.50,0.75,1.0])
# Out:
# 0.10      1.03460
# 0.25      2.61000
# 0.50      7.79000
# 0.75     24.44025
# 1.00    933.57000
# Name: Shipping Cost, dtype: float64

# %%
df4["Quantity"].quantile([0.1,0.25,0.50,0.75,1.0])
# Out:
# 0.10     1.0
# 0.25     2.0
# 0.50     3.0
# 0.75     5.0
# 1.00    14.0
# Name: Quantity, dtype: float64

# %%
df4.shape
# Out:
# (51290, 5)

# %%
df4_1=df4[(df4["Quantity"]>=2.0) & (df4["Quantity"]<=5.0)]

# %%
df4_1.shape
# Out:
# (33694, 5)

# %%
plt.boxplot(df4_1["Quantity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e40e5e30a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e40e5e3640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e40e46ad90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e40e5e3be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e40e5e3eb0>],
#  'means': []}

# %%
df4_2=df4_1[(df4_1["Shipping Cost"]>=2.61) & (df4_1["Shipping Cost"]<=24.44025)]

# %%
df4_2.shape
# Out:
# (17585, 5)

# %%
plt.boxplot(df4_2["Shipping Cost"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e40e409280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e40e409850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e40e415f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e40e409df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e40e432100>],
#  'means': []}

# %%
df4_3=df4_2[(df4_2["Discount"]>=0.0) & (df4_2["Discount"]<=0.2)]

# %%
df4_3.shape
# Out:
# (13990, 5)

# %%
plt.boxplot(df4_3["Discount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e40e4b03d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e40e4b0970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e40e4b0220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e40e4b0f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e40e49b220>],
#  'means': []}

# %%
df4_4=df4_3[(df4_3["Sales"]>=30.758625) & (df4_3["Sales"]<=251.053200)]

# %%
df4_4.shape
# Out:
# (11384, 5)

# %%
plt.boxplot(df4_4["Sales"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e40e94ef10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e40e95c4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e40e94ec40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e40e95ca90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e40e95cd60>],
#  'means': []}

# %%
df4_5=df4_4[(df4_4["Profit"]>=0.0) & (df4_4["Profit"]<=36.8100)]

# %%
df4_5.shape
# Out:
# (8451, 5)

# %%
plt.boxplot(df4_5["Profit"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e4289a2310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e4289a28b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e4289a2040>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e4289d0190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e4289d0490>],
#  'means': []}
