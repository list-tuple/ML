# %%
import pandas as pd

# %%
df = pd.read_excel("Global Superstore.xls","Orders")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.head(10)
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 5   22732    IN-2013-42360 2013-06-28 2013-07-01    Second Class    JM-15655
# 6   30570    IN-2011-81826 2011-11-07 2011-11-09     First Class    TS-21340
# 7   31192    IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
# 8   40155   CA-2014-135909 2014-10-14 2014-10-21  Standard Class    JW-15220
# 9   40936   CA-2012-116638 2012-01-28 2012-01-31    Second Class    JH-15985
#
#       Customer Name      Segment           City            State  ...  \
# ...

# %%
df.tail(5)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398  US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470  US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596  MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147  MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df["Profit"]
# Out:
# 0        762.1845
# 1       -288.7650
# 2        919.9710
# 3        -96.5400
# 4        311.5200
#            ...
# 51285      4.5000
# 51286     -1.1100
# 51287     11.2308
# 51288      2.4000
# 51289      1.8000
# Name: Profit, Length: 51290, dtype: float64

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df["Profit"].mean()
# Out:
# 28.61098247767587

# %%
df["Profit"].median()
# Out:
# 9.24

# %%
df["Profit"].mode()
# Out:
# 0    0.0
# Name: Profit, dtype: float64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375818
# std      174.340972      57.296810
# min    -6599.978000       0.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df.describe(include="all")
# Out:
# C:\Users\Lalith Eswar\AppData\Local\Temp\ipykernel_4380\1985922364.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
# C:\Users\Lalith Eswar\AppData\Local\Temp\ipykernel_4380\1985922364.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
#              Row ID        Order ID           Order Date            Ship Date  \
# count   51290.00000           51290                51290                51290
# unique          NaN           25035                 1430                 1464
# ...

# %%
df[["Market","Region","Profit","Sales"]]
# Out:
#        Market      Region    Profit     Sales
# 0          US        East  762.1845  2309.650
# 1        APAC     Oceania -288.7650  3709.395
# 2        APAC     Oceania  919.9710  5175.171
# 3          EU     Central  -96.5400  2892.510
# 4      Africa      Africa  311.5200  2832.960
# ...       ...         ...       ...       ...
# 51285    APAC  North Asia    4.5000    65.100
# 51286      US     Central   -1.1100     0.444
# 51287      US        West   11.2308    22.920
# 51288   LATAM       South    2.4000    13.440
# 51289   LATAM     Central    1.8000    61.380
#
# [51290 rows x 4 columns]

# %%
df.loc[0:10,"Market"]
# Out:
# 0         US
# 1       APAC
# 2       APAC
# 3         EU
# 4     Africa
# 5       APAC
# 6       APAC
# 7       APAC
# 8         US
# 9         US
# 10        US
# Name: Market, dtype: object

# %%
df.loc[0:10,"Sales"]
# Out:
# 0     2309.650
# 1     3709.395
# 2     5175.171
# 3     2892.510
# 4     2832.960
# 5     2862.675
# 6     1822.080
# 7     5244.840
# 8     5083.960
# 9     4297.644
# 10    4164.050
# Name: Sales, dtype: float64

# %%
df.loc[100:110,"Segment"]
# Out:
# 100       Consumer
# 101      Corporate
# 102       Consumer
# 103      Corporate
# 104       Consumer
# 105       Consumer
# 106    Home Office
# 107    Home Office
# 108       Consumer
# 109    Home Office
# 110      Corporate
# Name: Segment, dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.iloc[0:10,5]
# Out:
# 0    RH-19495
# 1    JR-16210
# 2    CR-12730
# 3    KM-16375
# 4     RH-9495
# 5    JM-15655
# 6    TS-21340
# 7    MB-18085
# 8    JW-15220
# 9    JH-15985
# Name: Customer ID, dtype: object

# %%
df[df["Profit"] >1000]["Profit"]
# Out:
# 8        1906.4850
# 12       1151.4000
# 14       1036.0800
# 17       3979.0800
# 23       1898.4000
#            ...
# 13013    1150.2000
# 14843    6719.9808
# 16062    2799.9840
# 19307    1038.4200
# 39564    2461.3200
# Name: Profit, Length: 147, dtype: float64

# %%
df[(df["Profit"] >1000) & (df["Sales"] >1000)]["Profit"]
# Out:
# 8        1906.4850
# 12       1151.4000
# 14       1036.0800
# 17       3979.0800
# 23       1898.4000
#            ...
# 13013    1150.2000
# 14843    6719.9808
# 16062    2799.9840
# 19307    1038.4200
# 39564    2461.3200
# Name: Profit, Length: 147, dtype: float64

# %%
df[df["Segment"] == "Consumer"][["Segment","Region","Profit","Sales"]]
# Out:
#         Segment   Region    Profit     Sales
# 0      Consumer     East  762.1845  2309.650
# 2      Consumer  Oceania  919.9710  5175.171
# 4      Consumer   Africa  311.5200  2832.960
# 6      Consumer  Oceania  564.8400  1822.080
# 7      Consumer  Oceania  996.4800  5244.840
# ...         ...      ...       ...       ...
# 51277  Consumer     West    8.0730    17.940
# 51278  Consumer   Africa   -6.4560     5.364
# 51281  Consumer    South    9.2000    84.000
# 51286  Consumer  Central   -1.1100     0.444
# 51289  Consumer  Central    1.8000    61.380
#
# [26518 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.loc[0:10,"Customer Name"]
# Out:
# 0          Rick Hansen
# 1        Justin Ritter
# 2         Craig Reiter
# 3     Katherine Murray
# 4          Rick Hansen
# 5          Jim Mitchum
# 6        Toby Swindell
# 7           Mick Brown
# 8            Jane Waco
# 9          Joseph Holt
# 10        Greg Maxwell
# Name: Customer Name, dtype: object

# %%
df.iloc[0:10,6]
# Out:
# 0         Rick Hansen
# 1       Justin Ritter
# 2        Craig Reiter
# 3    Katherine Murray
# 4         Rick Hansen
# 5         Jim Mitchum
# 6       Toby Swindell
# 7          Mick Brown
# 8           Jane Waco
# 9         Joseph Holt
# Name: Customer Name, dtype: object
